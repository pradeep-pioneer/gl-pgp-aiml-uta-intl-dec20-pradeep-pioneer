# %% [markdown]
# # Project - Bank Churn Prediction
#
# ## Description
#
# ### Background and Context
#
# Businesses like banks that provide service have to worry about the problem of 'Churn' i.e. customers leaving and joining another service provider. It is important to understand which aspects of the service influence a customer's decision in this regard. Management can concentrate efforts on the improvement of service, keeping in mind these priorities.
#
# ### Objective
#
# Given a Bank customer, build a neural network-based classifier that can determine whether they will leave or not in the next 6 months.
#
# ### Data Description
#
# The case study is from an open-source dataset from Kaggle. The dataset contains 10,000 sample points with 14 distinct features such as CustomerId, CreditScore, Geography, Gender, Age, Tenure, Balance, etc.
#
# #### Data Dictionary
#
# * **CustomerId:** Unique ID which is assigned to each customer
# * **Surname:** Last name of the customer
# * **CreditScore:** It defines the credit history of the customer.
# * **Geography:** A customer’s location
# * **Gender:** It defines the Gender of the customer
# * **Age:** Age of the customer
# * **Tenure:** Number of years for which the customer has been with the bank
# * **NumOfProducts:** It refers to the number of products that a customer has purchased through the bank.
# * **Balance:** Account balance
# * **HasCrCard:** It is a categorical variable that decides whether the customer has a credit card or not.
# * **EstimatedSalary:** Estimated salary
# * **isActiveMember:** It is a categorical variable that decides whether the customer is an active member of the bank or not ( Active member in the sense, using bank products regularly, making transactions, etc )
# * **Excited:** It is a categorical variable that decides whether the customer left the bank within six months or not. It can take two values.
# ```
#                     0=No ( Customer did not leave the bank )
#                     1=Yes ( Customer left the bank )
# ```
#
# ### Best Practices for Notebook :
#
# The notebook should be well-documented, with inline comments explaining the functionality of code and markdown cells containing comments on the observations and insights.
# The notebook should be run from start to finish in a sequential manner before submission.
# It is preferable to remove all warnings and errors before submission.
# The notebook should be submitted as an HTML file (.html) and as a notebook file (.ipynb)
#
# ### Submission Guidelines :
#
# 1. There are two parts to the submission:
#   1. A well commented Jupyter notebook [format - .ipynb]
#   2. File converted to HTML format
# 2. Any assignment found copied/ plagiarized with other groups will not be graded and awarded zero marks
# 3. Please ensure timely submission as any submission post-deadline will not be accepted for evaluation
# 4. Submission will not be evaluated if,
#   1. it is submitted post-deadline, or,
#   2. more than 2 files are submitted
# Happy Learning!!

# %% [markdown]
# # Scoring guide (Rubric) - Bank Churn Prediction
#
# | Criteria                                                          | Points |
# |:----------------------------------------------------------------- |-------:|
# |**Reading Dataset and Feature Elimination**                        |        |
# |- Read the dataset properly<br/>- Print the overview of the data (statistical summary, shape, info, etc)<br/>- Eliminate the unique features from the dataset with proper reasoning                                               | 5      |
# |**Perform an Exploratory Data Analysis on the data**               |        |
# |- Check whether the dataset is balanced or not <br/>- Bivariate analysis<br/>- Use appropriate visualizations to identify the patterns and insights<br/>- Any other exploratory deep dive                                               | 5      |
# |**Illustrate the insights based on EDA**                           |        |
# |- Key meaningful observations from Bivariate analysis              | 5      |
# |**Data Pre-processing**                                            |        |
# |- Split the target variable and predictors<br/>- Split the data into train and test<br/>- Rescale the data                                             | 10     |
# |**Model building**                                                 |        |
# |- Build Neural Network                                             | 10     |
# |**Model Performance Improvement**                                  |        |
# |- Comment on which metric is right for model performance evaluation and why?<br/>- Find the optimal threshold using ROC-AUC curves<br/>- Comment on model performance<br/>- Can model performance be improved? check and comment<br/>- Build another model to implement these improvements<br/>- Include all the model which were trained to reach at the final one                              | 15     |
# |**Model Performance Evaluation**                                   |        |
# |- Evaluate the model on different performance metrics and comment on the performance and scope of improvement                                | 5      |
# |**Conclusion and key takeaways**                                   |        |
# |- Final conclusion about the analysis                              | 2.5    |
# |**Notebook overall**                                               |        |
# |- Structure and flow - Well commented code                         | 2.5    |

# %% [markdown]
# # Prework
#
# In order for us to start loading the data and prepare for EDA and data preprocessing we need to prepare our environment - we need to set up either a Google colab notebook or a conda environment on our local machine.
#
# I am currently using a Google Colab Notebook but all the steps can also be performed using a conda installation on your local machine. If you use Google colab you can simply start by importing the tensorflow, pandas, numpy, sklearn & seaborn packages into your notebook, but if you want to run the notebook locally - in the next section I have described how to set up the conda environment.
#
# ## Environment Setup
#
# I will be using python 3.7 in a python virtual environment setup using miniconda. The below list lists down the pre-requisites for the environment.
#
# 1. [Miniconda](https://docs.conda.io/en/latest/miniconda.html)
# 2. [Docker Desktop](https://www.docker.com/products/docker-desktop): to be able to run GPU tools in a docker environment - I have a an NVIDIA RTX 2070 on my machine so I will try to utilize the GPU wherever possible.
# 3. Visual Studio Code: I will be using VS Code as an IDE for editing code (except for code in notebooks)
#
# The next steps defined in this file are based on the [video guide](https://youtu.be/qrkEYf-YDyI) by [Prof. Jeff Heaton](https://www.youtube.com/channel/UCR1-GEpyOPzT2AO4D_eifdw) from [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx).
#
# ### Step 1
#
# After installing the above pre-requistes it's the time for us to setup our conda environment. I have 2 environments - for CPU and for GPU. The environment dependency files are with the following names and the contents are listed below for each:
#
# #### CPU Environment File (I have named it ```gl-tensorflow.yml```)
# ```yaml
# name: gl-tensorflow
# dependencies:
#     - python=3.7
#     - pip>=20.0
#     - jupyter
#     - tensorflow=2.0
#     - scikit-learn
#     - scipy
#     - pandas>=1.0.1
#     - pandas-datareader
#     - matplotlib
#     - pillow
#     - tqdm
#     - requests
#     - h5py
#     - pyyaml
#     - flask
#     - boto3
#     - xgboost
#     - openpyxl
#     - scikit-learn-intelex
#     - seaborn
#     - statsmodels
#     - imbalanced-learn
#     - pip:
#         - bayesian-optimization
#         - gym
#         - kaggle
# ```
#
# #### GPU Environment File (I have named it ```gl-tensorflow-gpu.yml```)
# ```yaml
# name: gl-tensorflow-gpu
# dependencies:
#     - python=3.7
#     - pip>=20.0
#     - jupyter
#     - tensorflow-gpu=2.1.0
#     - scikit-learn
#     - scipy
#     - pandas
#     - pandas-datareader
#     - matplotlib
#     - pillow
#     - tqdm
#     - requests
#     - h5py
#     - pyyaml
#     - flask
#     - boto3
#     - xgboost
#     - openpyxl
#     - scikit-learn-intelex
#     - seaborn
#     - statsmodels
#     - imbalanced-learn
#     - pip:
#         - bayesian-optimization
#         - gym
#         - kaggle
# ```
#
# To create the environment I will execute the following commands from a terminal/command prompt (on windows - you can run the cmd process).
#
# ```bash
# # install jupyter notebooks
# conda install -y jupyter
# # navigate to the root of the repository
# cd [REPO_ROOT]
# conda env create -v -f <gl-tensorflow.yml | gl-tensorflow-gpu.yml>
# conda activate <gl-tensorflow | gl-tensorflow-gpu>
# # for CPU tensorflow env
# python -m ipykernel install --user --name gl-tensorflow --display-name "GL-Python-3.7 (tensorflow)"
# # for GPU tensorflow env
# python -m ipykernel install --user --name gl-tensorflow-gpu --display-name "GL-Python-3.7 (tensorflow-gpu)"
# ```
#
# ### Step 2
#
# Now it's time to check our environments. We can execute the following commnads from the root of our repository
#
# ```bash
# conda activate <gl-tensorflow | gl-tensorflow-gpu>
# jupyter notebook
# ```
#
# This will start the jupyter notebooks and open the default web browser with the user interface for jupyter notebooks.
#
# To check the environment you can create a new notebook and paste the following code in an empty cell.
# ```python
# import tensorflow as tf
# import sys # for checking the version of python
# import tensorflow.keras
# import sklearn as sklearn
# import pandas as pandas
# print("Python Version:", sys.version)
# print("Tensor Flow Version:", tf.__version__)
# print("Keras Version:", tensorflow.keras.__version__)
# print("SciKit Learn Version:", sklearn.__version__)
# print("Pandas Version:", pandas.__version__)
# gpus = tf.config.list_physical_devices('GPU')
# gpustatus="is available" if len(gpus)>0 else "NOT AVAILABLE"
# print("GPU", gpustatus)
# ```
#
# If there are no errors when executing the first code cell (second cell in the notebook) - the environment has been setup successfully.

# %%
## Environment Check
import numpy as np
import pandas as pd
import scipy
from scipy.stats import zscore

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn import metrics
from sklearn.model_selection  import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
print("Python Version:", sys.version)
print("Numpy Version:", np.__version__)
print("Pandas Version:", pd.__version__)
print("Scipy Version:", scipy.__version__)
print("Matplotlib Version:", matplotlib.__version__)
print("Seaborn Version:", sns.__version__)
print("SciKit Learn Version:", sklearn.__version__)
print("Tensor Flow Version:", tf.__version__)
print("Keras Version:", tensorflow.keras.__version__)

gpus = tf.config.list_physical_devices('GPU')
gpustatus="is available" if len(gpus)>0 else "NOT AVAILABLE"
print("GPU", gpustatus)
# Out:
# Python Version: 3.7.11 (default, Jul  3 2021, 18:01:19)
# [GCC 7.5.0]
# Numpy Version: 1.19.5
# Pandas Version: 1.1.5
# Scipy Version: 1.4.1
# Matplotlib Version: 3.2.2
# Seaborn Version: 0.11.1
# SciKit Learn Version: 0.22.2.post1
# Tensor Flow Version: 2.5.0
# Keras Version: 2.5.0
# GPU NOT AVAILABLE

# %% [markdown]
# # Reading Dataset and Feature Elimination
# We will start with loading the data in a dataframe. We will check if we are running in Google Colab and if we are running in colab then we will load the dataset from the google drive (by mapping it to a local folder) else we will simply load the data from a local file.
#
# The following are required:
# - Read the dataset properly
# - Print the overview of the data (statistical summary, shape, info, etc)
# - Eliminate the unique features from the dataset with proper reasoning
#
# ## Read the dataset properly

# %%
running_in_colab = False
if 'google.colab' in str(get_ipython()):
  print('We are in Colab - mapping google drive and loading data from local folder mapped to google drive.')
  from google.colab import drive
  drive.mount('/content/drive')
  running_in_colab = True
else:
  print('We are running locally!')
  running_in_colab = False
# Out:
# We are in Colab - mapping google drive and loading data from local folder mapped to google drive.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_bank_customers = pd.DataFrame()
if running_in_colab:
  df_bank_customers = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/datasets/bank.csv")
else:
  df_bank_customers = pd.read_csv("datasets/bank.csv") ## assuming that it located in a local folder where the notebook is.

df_bank_customers.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Eliminate the unique features from the dataset with proper reasoning
# We see that there are a few columns in the data which don't add any value to our analysis and would have to be dropped before model building & EDA to be able to focus on important data points. These columns are:
# - ```RowNumber``` this is just a running number assigned to each row in the dataset.
# - ```CustomerId``` this is a unique customer identifier (probably in the bank database).
# - ```Surname``` this is the last name (otherwise known as family name in some countries).
#
# So we will just drop these from our dataset.
#
# ## Print the overview of the data (statistical summary, shape, info, etc)
# We will analyze the data to understand the following:
# 1. Check the shape of the data.
# 2. Find missing values in the data.
# 3. Check the data types of various columns (int vs float vs object).
# 3. Statistical Summary for the Numerical Values (min, max, mean, standard deviation, 25th, 50th & 75th percentile)
# 4. Unique Value Counts for Categorical Values

# %%
# Eliminate the unique features from the dataset with proper reasoning
df_bank_customers_cleaned = df_bank_customers.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)
df_bank_customers_cleaned.head()
# Out:
#    CreditScore Geography  Gender  ...  IsActiveMember  EstimatedSalary  Exited
# 0          619    France  Female  ...               1        101348.88       1
# 1          608     Spain  Female  ...               1        112542.58       0
# 2          502    France  Female  ...               0        113931.57       1
# 3          699    France  Female  ...               0         93826.63       0
# 4          850     Spain  Female  ...               1         79084.10       0
#
# [5 rows x 11 columns]

# %%
# Check the shape of the data.
print(f'Cleaned Data Shape:\n{df_bank_customers_cleaned.shape}')
# Out:
# Cleaned Data Shape:
# (10000, 11)

# %%
# Check missing values
print(f'Null Values: {df_bank_customers_cleaned.isnull().sum().sum()}')
print(f'Na Values: {df_bank_customers_cleaned.isna().sum().sum()}')
# Out:
# Null Values: 0
# Na Values: 0

# %%
# Check the data types of various columns (int vs float vs object).
df_bank_customers_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %%
# Statistical Summary for the Numerical Values (min, max, mean, standard deviation, 25th, 50th & 75th percentile)
df_bank_customers_cleaned.describe()
# Out:
#         CreditScore           Age  ...  EstimatedSalary        Exited
# count  10000.000000  10000.000000  ...     10000.000000  10000.000000
# mean     650.528800     38.921800  ...    100090.239881      0.203700
# std       96.653299     10.487806  ...     57510.492818      0.402769
# min      350.000000     18.000000  ...        11.580000      0.000000
# 25%      584.000000     32.000000  ...     51002.110000      0.000000
# 50%      652.000000     37.000000  ...    100193.915000      0.000000
# 75%      718.000000     44.000000  ...    149388.247500      0.000000
# max      850.000000     92.000000  ...    199992.480000      1.000000
#
# [8 rows x 9 columns]

# %%
# Unique Value Counts for Categorical Values
df_bank_customers_cleaned.nunique()
# Out:
# CreditScore         460
# Geography             3
# Gender                2
# Age                  70
# Tenure               11
# Balance            6382
# NumOfProducts         4
# HasCrCard             2
# IsActiveMember        2
# EstimatedSalary    9999
# Exited                2
# dtype: int64

# %% [markdown]
# # Perform an Exploratory Data Analysis on the data
# - Check whether the dataset is balanced or not
# - Bivariate analysis
# - Use appropriate visualizations to identify the patterns and insights
# - Any other exploratory deep dive
#
# In order to understand the data and also spot any patterns and skewness we will do Univariate, Bivariate & Multivariate visualization of our data.
#
# ## Check whether the dataset is balanced or not
# We can do a countplot on the target variable to check if we have an imbalanced dataset.

# %%
sns.countplot(data= df_bank_customers_cleaned, x='Exited')

# %% [markdown]
# ## Check whether the dataset is balanced or not: Result
# As we can see it is an imbalance dataset - we have less (underrepresented) positive class compared to negative (20:80) - we have only 20% of data representing the positive class. We will deal with the imbalance in the dataset using the following techniques (after building a simple model from the dataset to get an idea of how data imbalance affects the model performance):
# - Classweights
# - Tuning the bias of the output layer
# - Oversampling

# %% [markdown]
# ## Bivariate Analysis
# ### Pairplot
# We will use pairplot to plot all numerical values and understand how they relate to each other first and then we will go ahead and deep dive into interesting pairs individually using suitable visualizations.

# %%
sns.pairplot(data=df_bank_customers_cleaned,diag_kind='kde')

# %% [markdown]
# ### Categorical Values Bivariate analysis
# While using the above pairplot we can see a good pairwise relationship between numerical/continuous values - the pairplots are not adequate to give us a good idea of intrinsic distribution relationships between discrete values & other data, ex: how does number of products affect the credit score and where do we see the clusters of churned customers.
#
# For this task we are going to use the catplot function of seaborn.

# %%
sns.catplot(data=df_bank_customers_cleaned, x='NumOfProducts', y='CreditScore', hue='Exited')

# %%
sns.catplot(data=df_bank_customers_cleaned, x='IsActiveMember', y='Balance', hue='Exited')

# %%
sns.catplot(data=df_bank_customers_cleaned, x='HasCrCard', y='CreditScore', hue='Exited')

# %%
sns.catplot(data=df_bank_customers_cleaned, x='IsActiveMember', y='EstimatedSalary', hue='Exited')

# %%
sns.catplot(data=df_bank_customers_cleaned, x='HasCrCard', y='EstimatedSalary', hue='Exited')

# %%
sns.catplot(data=df_bank_customers_cleaned, x='Tenure', y='Balance', hue='Exited')

# %%
sns.scatterplot(data=df_bank_customers_cleaned, x='Age', y='CreditScore', hue='Exited')

# %%
sns.scatterplot(data=df_bank_customers_cleaned, x='Age', y='Balance', hue='Exited')

# %%
sns.scatterplot(data=df_bank_customers_cleaned, x='Age', y='EstimatedSalary', hue='Exited')

# %%
sns.scatterplot(data=df_bank_customers_cleaned, x="Balance", y="EstimatedSalary", hue="Exited")

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(df_bank_customers_cleaned.corr(),
            annot=True,
            linewidths=.1,
            center=0,
            cbar=False,
            cmap="YlGnBu",
            ax=ax)
plt.show()

# %% [markdown]
# ### Observations from the EDA
# - We don't see high colinearity/correlation between most of the independent variables.
# - We do see a mild effect of age on the customer churn (exited flag)
# - Almost all the examples that we have with more than 3 products have churned irrespective of their credit scores.
# - We do see higher density of data around lower age groups which means that we have more examples of people between 25-40 years.
# - There are **strange examples** with 0 as balance (and they look like missing values) because we have a strange straight line of such zero balance account.
# - These zero balance accounts are evenly distributed across all kinds of data - ex: age, salary etc.
#
# We would need to deep dive a bit to understand these zero balance accounts.

# %%
df_bank_customers_zero_bal = df_bank_customers_cleaned[df_bank_customers_cleaned['Balance']==0]
print(f'Zero Balance Shape:\n{df_bank_customers_zero_bal.shape}')
print(f'Zero Balance Unique Values:\n{df_bank_customers_zero_bal.nunique()}')
# Out:
# Zero Balance Shape:
# (3617, 11)
# Zero Balance Unique Values:
# CreditScore         434
# Geography             2
# Gender                2
# Age                  67
# Tenure               11
# Balance               1
# NumOfProducts         4
# HasCrCard             2
# IsActiveMember        2
# EstimatedSalary    3617
# Exited                2
# dtype: int64

# %%
df_bank_customers_zero_bal.head(100)
# Out:
#      CreditScore Geography  Gender  ...  IsActiveMember  EstimatedSalary  Exited
# 0            619    France  Female  ...               1        101348.88       1
# 3            699    France  Female  ...               0         93826.63       0
# 6            822    France    Male  ...               1         10062.80       0
# 11           497     Spain    Male  ...               0         76390.01       0
# 12           476    France  Female  ...               0         26260.98       0
# ..           ...       ...     ...  ...             ...              ...     ...
# 252          681    France  Female  ...               1        170968.99       0
# 254          696     Spain    Male  ...               0        176713.47       0
# 255          766     Spain    Male  ...               1         34283.23       0
# 256          727    France    Male  ...               1        198637.34       0
# 266          498    France    Male  ...               1        148528.24       0
#
# ...

# %% [markdown]
# ### Zero Balance Accounts
#
# Looking at the data we cannot find anything which might point to these being missing values - it could be simply the side effect of the time when the data was extracted having a few customers withdrawn their funds when the snapshot was taken.

# %% [markdown]
# # Data Pre-processing
#
# - Split the target variable and predictors
# - Split the data into train and test
# - Rescale the data
#
# ## Split the target variable and predictors

# %%
X_bank_customers = df_bank_customers_cleaned.drop('Exited', axis=1)
y_bank_customers = df_bank_customers_cleaned['Exited']
X_bank_customers = pd.get_dummies(X_bank_customers, drop_first=True)

# %% [markdown]
# ## Split the data into train and test
#
# ### Pre-requisites
# Before being able to split the data - we need to treat the categorical variables like ```Gender``` and ```Geography```.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_bank_customers, y_bank_customers, test_size = 0.2, random_state = 0, stratify = y_bank_customers)
X_train.head()
# Out:
#       CreditScore  Age  Tenure  ...  Geography_Germany  Geography_Spain  Gender_Male
# 493           531   47       6  ...                  0                0            0
# 6839          724   36       6  ...                  1                0            1
# 170           484   29       4  ...                  0                0            0
# 4958          655   37       6  ...                  0                0            1
# 4271          465   33       5  ...                  0                0            1
#
# [5 rows x 11 columns]

# %% [markdown]
# ## Rescale the data
# We will fit the standard scaler on training data and apply the transformations to test data and training data.

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train
# Out:
# array([[-1.24021723,  0.77986083,  0.35390313, ..., -0.57812007,
#         -0.57504086, -1.09665089],
#        [ 0.75974873, -0.27382717,  0.35390313, ...,  1.72974448,
#         -0.57504086,  0.91186722],
#        [-1.72725557, -0.9443559 , -0.3390904 , ..., -0.57812007,
#         -0.57504086, -1.09665089],
#        ...,
#        [-0.51484098,  0.87565065,  1.39339343, ...,  1.72974448,
#         -0.57504086,  0.91186722],
#        [ 0.73902369, -0.36961699, -1.03208393, ..., -0.57812007,
#         -0.57504086, -1.09665089],
#        [ 0.95663657, -1.32751517,  0.35390313, ..., -0.57812007,
#          1.73900686,  0.91186722]])

# %% [markdown]
# # Model building
#
# We will build a fully connected network with 3 layers, the first input layer will be a ```Dense``` layer with neurons equal to features in our in our training data (independent variables), second layer will be another ```Dense``` layer 128 neurons. In the output layer (again ```Dense``` layer) we will have only one nueron with **Sigmoid** as the activation function because we only have 2 output classes.
#
# Here is a layout of our Neural Network:
# 1. Input Layer:
#   1. Type: ```Dense```
#   2. Neurons: 11
#   3. Activation: ```relu```
# 2. First Hidden Layer:
#   1. Type: ```Dense```
#   2. Neurons: 128
#   3. Activation: ```relu```
# 3. Output Layer:
#   1. Type: ```Dense```
#   2. Neurons: 1
#   3. Activation: ```sigmoid```
#
# In addition we will use the following parameters for the Network.
#
# - **Optimizer**: ```adam```
# - **Loss**: ```BinaryCrossentropy```
#
# We will create a helper function to help us recompile the model several times with different parameters.
# We will care for the following *metrics* while building our model.
# * **Accuracy**
# * **Precision**
# * **Recall**
# * **TruePositives**
# * **FalsePositives**
# * **TrueNegatives**
# * **FalseNegatives**
# * **AUC**
# * **Precision Recall Curve (PRC)**

# %%
model_metrics = [
      keras.metrics.MeanSquaredError(name='mse'),
      keras.metrics.TruePositives(name='t_pos'),
      keras.metrics.FalsePositives(name='f_pos'),
      keras.metrics.TrueNegatives(name='t_neg'),
      keras.metrics.FalseNegatives(name='f_neg'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR')
]
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %%
def create_model(metrics=model_metrics, optimizer = keras.optimizers.Adam(learning_rate=0.001), loss=keras.losses.BinaryCrossentropy(), classifier_bias=None):
  if classifier_bias is not None:
    classifier_bias = tf.keras.initializers.Constant(classifier_bias)
  model = Sequential()
  model.add(Dense(X_train.shape[1], activation='relu', input_dim = X_train.shape[1]))
  model.add(Dense(128, activation='relu'))
  model.add(Dense(1, activation='sigmoid', bias_initializer=classifier_bias))
  model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

  return model

# %%
model = create_model()
training_history_1 = model.fit(X_train, y_train, epochs=30, callbacks=[early_stopping], validation_split = 0.2, batch_size=256, verbose=True)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 3s 47ms/step - loss: 0.4998 - mse: 0.1607 - t_pos: 0.0000e+00 - f_pos: 0.0000e+00 - t_neg: 5071.0000 - f_neg: 1329.0000 - accuracy: 0.7923 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6278 - prc: 0.3124 - val_loss: 0.4657 - val_mse: 0.1468 - val_t_pos: 0.0000e+00 - val_f_pos: 0.0000e+00 - val_t_neg: 1299.0000 - val_f_neg: 301.0000 - val_accuracy: 0.8119 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6734 - val_prc: 0.3075
# Epoch 2/30
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4801 - mse: 0.1538 - t_pos: 10.0000 - f_pos: 4.0000 - t_neg: 5067.0000 - f_neg: 1319.0000 - accuracy: 0.7933 - precision: 0.7143 - recall: 0.0075 - auc: 0.6850 - prc: 0.3745 - val_loss: 0.4507 - val_mse: 0.1418 - val_t_pos: 1.0000 - val_f_pos: 7.0000 - val_t_neg: 1292.0000 - val_f_neg: 300.0000 - val_accuracy: 0.8081 - val_precision: 0.1250 - val_recall: 0.0033 - val_auc: 0.7145 - val_prc: 0.3467
# ...

# %%
def see_loss(history, label, n):
  # Use a log scale on y-axis to show the wide range of values.
  plt.semilogy(history.epoch, history.history['loss'],
               label='Train ' + label)
  plt.semilogy(history.epoch, history.history['val_loss'],
               label='Val ' + label,
               linestyle="--")
  plt.xlabel('Epoch')
  plt.ylabel('Loss')

# %%
def see_mse(history, label, n):
  # Use a log scale on y-axis to show the wide range of values.
  plt.semilogy(history.epoch, history.history['mse'],
               label='Train ' + label)
  plt.semilogy(history.epoch, history.history['val_mse'],
               label='Val ' + label,
               linestyle="--")
  plt.xlabel('Epoch')
  plt.ylabel('MSE')

# %%
see_loss(training_history_1, "Loss", 0)

# %%
see_mse(training_history_1, "MSE", 0)

# %%
def create_confusion_matrix(truth, predicted):
  cm = confusion_matrix(truth, predicted > 0.5)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(0.5))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')
  print('True Negatives: ', cm[0][0])
  print('False Positives: ', cm[0][1])
  print('False Negatives: ', cm[1][0])
  print('True Positives: ', cm[1][1])
  print('Total Positives: ', np.sum(cm[1]))

# %%
y_predict = model.predict(X_test)
create_confusion_matrix(y_test, y_predict)
# Out:
# True Negatives:  1537
# False Positives:  56
# False Negatives:  238
# True Positives:  169
# Total Positives:  407

# %%
performance = model.evaluate(X_test, y_test, verbose=True)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.3539 - mse: 0.1085 - t_pos: 169.0000 - f_pos: 56.0000 - t_neg: 1537.0000 - f_neg: 238.0000 - accuracy: 0.8530 - precision: 0.7511 - recall: 0.4152 - auc: 0.8453 - prc: 0.6718

# %%
model_performance_df = pd.DataFrame(index=['loss', 'mse', 'true positives', 'false positives', 'true negatives', 'false negatives', 'accuracy', 'precision', 'recall', 'auc', 'precison recall curve'])
model_performance_df['values'] = performance

# %%
model_performance_df.head(100)
# Out:
#                             values
# loss                      0.353934
# mse                       0.108519
# true positives          169.000000
# false positives          56.000000
# true negatives         1537.000000
# false negatives         238.000000
# accuracy                  0.853000
# precision                 0.751111
# recall                    0.415233
# auc                       0.845327
# precison recall curve     0.671752

# %% [markdown]
# # Model Performance Improvement
#
# ## How is the current model performing? (Comment on model performance)
# The current model performance is not very good - two of the three key matrices that we care about are not having their best values - which takes us to the next question.
#
# ## Comment on which metric is right for model performance evaluation and why?
#
# On a very high level we care about three key matrices:
# * Accuracy: Informally, accuracy is the fraction of predictions our model got right, It is formalized as Correct Predictions / All Predictions.
# * Precision: It helps in answering - What proportion of positive identifications was actually correct? It is calculated as True Positives / True Positives + False Positives
# * Recall: What proportion of actual positives was identified correctly? It is calculated as True Positives/True Positives + False Negatives.
#
# **Why do we care about these metrics?**
# Our goal is to be able to predict the potential churn customers which the bank might end up loosing, while accuracy gives us an indication as to how many predictions the model is able to make are near truth - it doesn't indicate the success rate for the classes that we care about the most. More specifically accuracy is not good indicator if we want our model to be really good in predicting one specific class to maximum possible correctness.
#
# Understanding the business implications of False Positives & False Negatives are listed below:
# 1. False Positives: If our model produces a lot of False Positives then we waste resources on customers who actually wouldn't have churned (same could have been used on other customer who actually churned).
# 2. False Negatives: If your model generates a lot of False Negatives then we would loose customers leading to revenue loss.
#
# Now with this and the above definition we can see that we would want to have a good precision & recall so that our model is able to tell us the maximum potential customers who might churn.

# %% [markdown]
# ## Checking AUC & PRC (precision-recall curve)

# %%
def plot_metrics(history):
  metrics = ['prc', 'auc']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

# %%
plot_metrics(training_history_1)

# %%
def plot_prc(name, labels, predictions):
    precision, recall, _ = sklearn.metrics.precision_recall_curve(labels, predictions)

    plt.plot(precision, recall, label=name, linewidth=2)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %%
plot_prc("Test Baseline", y_test, y_predict)

# %% [markdown]
# ## Can model performance be improved?
#
# The model performance is suffering because we have imbalanced dataset, there are a few things we can play with to see if we can get better results. We will try the following:
# 1. Changing the Classweights: We can configure the class weights so that the model can pay special attention to the minority class and adapt so that we don't have a model which is biased toward the majority class.
# 2. Tuning the bias for output layer: We can tweak the bias for output layer so that it favors the class that we care about rather than the majority class.
# 3. Oversampling the data: We can oversample the data using the ```tf.data``` module available in tensorflow.
#
# Let's start with first option.
#
# ### Class weights
# #### Calculate class weights
# We can calculate the classweights by ```(1 / class observations) * (total / 2.0)``` for each class.

# %%
neg, pos = np.bincount(df_bank_customers_cleaned['Exited'])
print(f'Negatives: {neg}')
print(f'Positives: {pos}')
# Out:
# Negatives: 7963
# Positives: 2037

# %%
weight_for_neg = (1 / neg) * (neg + pos / 2.0)
weight_for_pos = (1 / pos) * (neg + pos / 2.0)
output_weights = {0: weight_for_neg, 1: weight_for_pos}
print(f'Output weights: {output_weights}')
weighted_model = create_model()
training_history_2 = weighted_model.fit(
    X_train, 
    y_train, 
    epochs=30, 
    callbacks=[early_stopping], 
    validation_split = 0.2, 
    batch_size=256,
    class_weight=output_weights,
    verbose=True)
# Out:
# Output weights: {0: 1.1279040562602036, 1: 4.409180166912126}
# Epoch 1/30
# 25/25 [==============================] - 3s 45ms/step - loss: 1.1720 - mse: 0.1954 - t_pos: 897.0000 - f_pos: 1688.0000 - t_neg: 4976.0000 - f_neg: 839.0000 - accuracy: 0.6992 - precision: 0.3470 - recall: 0.5167 - auc: 0.6943 - prc: 0.4333 - val_loss: 0.5921 - val_mse: 0.2017 - val_t_pos: 187.0000 - val_f_pos: 354.0000 - val_t_neg: 945.0000 - val_f_neg: 114.0000 - val_accuracy: 0.7075 - val_precision: 0.3457 - val_recall: 0.6213 - val_auc: 0.7398 - val_prc: 0.3945
# Epoch 2/30
# ...

# %%
see_loss(training_history_2, "Loss", 0)

# %%
see_mse(training_history_2, "Loss", 0)

# %%
plot_metrics(training_history_2)

# %%
y_predict_weighted = weighted_model.predict(X_test)
create_confusion_matrix(y_test, y_predict_weighted)
# Out:
# True Negatives:  1300
# False Positives:  293
# False Negatives:  109
# True Positives:  298
# Total Positives:  407

# %%
performance_weighted = weighted_model.evaluate(X_test, y_test, verbose=True)
model_performance_weighted_df = pd.DataFrame(index=[
    'loss', 'mse', 'true positives', 'false positives', 'true negatives', 'false negatives', 
    'accuracy', 'precision', 'recall', 'auc', 'precison recall curve'])
model_performance_weighted_df['values'] = performance_weighted
model_performance_weighted_df.head(100)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4407 - mse: 0.1413 - t_pos: 298.0000 - f_pos: 293.0000 - t_neg: 1300.0000 - f_neg: 109.0000 - accuracy: 0.7990 - precision: 0.5042 - recall: 0.7322 - auc: 0.8495 - prc: 0.6867
#                             values
# loss                      0.440716
# mse                       0.141253
# true positives          298.000000
# false positives         293.000000
# true negatives         1300.000000
# false negatives         109.000000
# accuracy                  0.799000
# precision                 0.504230
# recall                    0.732187
# auc                       0.849547
# precison recall curve     0.686695

# %% [markdown]
# ### Adjusting the Class Weights
# #### Outcome
# There is an improvement on model performance in terms of recall after adjusting the class weights but now the precision has dropped significantly. This means that we have traded precison for recall. All the three metrics that we care for still remain quite low.
#
# ### Tuning the bias for output layer:
# We will now tune the bias for the output layer to try and tune the outcome from the output layer, we can use the following formula to calculate the values for the bias: ```log(pos/neg)```.

# %%
output_layer_bias = np.log([pos/neg])
print(f'Updated Output Bias: {output_layer_bias}')
# Out:
# Updated Output Bias: [-1.36332768]

# %%
model_biased = create_model(classifier_bias=output_layer_bias)
training_history_3 = model_biased.fit(
    X_train, 
    y_train, 
    epochs=50, 
    callbacks=[early_stopping], 
    validation_split = 0.2, 
    batch_size=256,
    verbose=True)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 3s 47ms/step - loss: 0.4713 - mse: 0.1482 - t_pos: 398.0000 - f_pos: 376.0000 - t_neg: 6288.0000 - f_neg: 1338.0000 - accuracy: 0.7960 - precision: 0.5142 - recall: 0.2293 - auc: 0.7209 - prc: 0.4460 - val_loss: 0.4131 - val_mse: 0.1298 - val_t_pos: 64.0000 - val_f_pos: 53.0000 - val_t_neg: 1246.0000 - val_f_neg: 237.0000 - val_accuracy: 0.8188 - val_precision: 0.5470 - val_recall: 0.2126 - val_auc: 0.7671 - val_prc: 0.4422
# Epoch 2/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.4265 - mse: 0.1346 - t_pos: 292.0000 - f_pos: 176.0000 - t_neg: 4895.0000 - f_neg: 1037.0000 - accuracy: 0.8105 - precision: 0.6239 - recall: 0.2197 - auc: 0.7764 - prc: 0.4976 - val_loss: 0.3976 - val_mse: 0.1241 - val_t_pos: 90.0000 - val_f_pos: 71.0000 - val_t_neg: 1228.0000 - val_f_neg: 211.0000 - val_accuracy: 0.8238 - val_precision: 0.5590 - val_recall: 0.2990 - val_auc: 0.7875 - val_prc: 0.5127
# Epoch 3/50
# ...

# %%
see_loss(training_history_3, "Loss", 0)

# %%
see_mse(training_history_3, "Loss", 0)

# %%
plot_metrics(training_history_3)

# %%
y_predict_biased = model_biased.predict(X_test)
create_confusion_matrix(y_test, y_predict_biased)
# Out:
# True Negatives:  1514
# False Positives:  79
# False Negatives:  212
# True Positives:  195
# Total Positives:  407

# %%
performance_biased = model_biased.evaluate(X_test, y_test, verbose=True)
model_performance_biased_df = pd.DataFrame(index=[
    'loss', 'mse', 'true positives', 'false positives', 'true negatives', 'false negatives', 
    'accuracy', 'precision', 'recall', 'auc', 'precison recall curve'])
model_performance_biased_df['values'] = performance_biased
model_performance_biased_df.head(100)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.3490 - mse: 0.1057 - t_pos: 195.0000 - f_pos: 79.0000 - t_neg: 1514.0000 - f_neg: 212.0000 - accuracy: 0.8545 - precision: 0.7117 - recall: 0.4791 - auc: 0.8454 - prc: 0.6890
#                             values
# loss                      0.348983
# mse                       0.105735
# true positives          195.000000
# false positives          79.000000
# true negatives         1514.000000
# false negatives         212.000000
# accuracy                  0.854500
# precision                 0.711679
# recall                    0.479115
# auc                       0.845385
# precison recall curve     0.689022

# %% [markdown]
# ### Combining adjusted Class Weights and Output Layer Bias
#
# Let see if we can get any better performance by adjusting both the Class Weights and Bias for output layer.

# %%
model_weighted_biased = create_model(classifier_bias=output_layer_bias)
training_history_4 = model_weighted_biased.fit(
    X_train, 
    y_train, 
    epochs=30, 
    #callbacks=[early_stopping], 
    validation_split = 0.2, 
    batch_size=256,
    class_weight=output_weights,
    verbose=True)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 3s 47ms/step - loss: 1.2051 - mse: 0.1873 - t_pos: 849.0000 - f_pos: 1441.0000 - t_neg: 5223.0000 - f_neg: 887.0000 - accuracy: 0.7229 - precision: 0.3707 - recall: 0.4891 - auc: 0.6979 - prc: 0.4271 - val_loss: 0.6438 - val_mse: 0.2197 - val_t_pos: 224.0000 - val_f_pos: 418.0000 - val_t_neg: 881.0000 - val_f_neg: 77.0000 - val_accuracy: 0.6906 - val_precision: 0.3489 - val_recall: 0.7442 - val_auc: 0.7681 - val_prc: 0.4376
# Epoch 2/30
# 25/25 [==============================] - 0s 4ms/step - loss: 0.9905 - mse: 0.1907 - t_pos: 967.0000 - f_pos: 1351.0000 - t_neg: 3720.0000 - f_neg: 362.0000 - accuracy: 0.7323 - precision: 0.4172 - recall: 0.7276 - auc: 0.8021 - prc: 0.5232 - val_loss: 0.5644 - val_mse: 0.1880 - val_t_pos: 218.0000 - val_f_pos: 367.0000 - val_t_neg: 932.0000 - val_f_neg: 83.0000 - val_accuracy: 0.7188 - val_precision: 0.3726 - val_recall: 0.7243 - val_auc: 0.8037 - val_prc: 0.4946
# Epoch 3/30
# ...

# %%
see_loss(training_history_4, "Loss", 0)

# %%
see_mse(training_history_4, "MSE", 0)

# %%
plot_metrics(training_history_4)

# %%
y_predict_weighted_biased = model_weighted_biased.predict(X_test)
create_confusion_matrix(y_test, y_predict_weighted_biased)
# Out:
# True Negatives:  1299
# False Positives:  294
# False Negatives:  116
# True Positives:  291
# Total Positives:  407

# %%
performance_weighted_biased = model_weighted_biased.evaluate(X_test, y_test, verbose=True)
model_performance_weighted_biased_df = pd.DataFrame(index=[
    'loss', 'mse', 'true positives', 'false positives', 'true negatives', 'false negatives', 
    'accuracy', 'precision', 'recall', 'auc', 'precison recall curve'])
model_performance_weighted_biased_df['values'] = performance_weighted_biased
model_performance_weighted_biased_df.head(100)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4483 - mse: 0.1455 - t_pos: 291.0000 - f_pos: 294.0000 - t_neg: 1299.0000 - f_neg: 116.0000 - accuracy: 0.7950 - precision: 0.4974 - recall: 0.7150 - auc: 0.8485 - prc: 0.6684
#                             values
# loss                      0.448256
# mse                       0.145489
# true positives          291.000000
# false positives         294.000000
# true negatives         1299.000000
# false negatives         116.000000
# accuracy                  0.795000
# precision                 0.497436
# recall                    0.714988
# auc                       0.848526
# precison recall curve     0.668442

# %% [markdown]
# ### Adjusting the Weights & Biases: Outcome
#
# Looking at the outcome of all three approaches we can say that they model is struggling to find the right signals to predict the **Positive** class because of the imbalanced data.
#
# #### Vanilla Model
# The default model without any tweak has a very low recall because it is not able to see enough examples with respect to positive class to correctly built correct paths for improving the recall.
#
# #### Model with adjusted class weights
# The model with adjusted weights performs poorly with the precision scores.
#
# #### Model with adjusted biases
# This model has performance similar to Vanilla model (i.e. adjusting bias did change anything). **It might be interesting to adjust the biases after training the vanilla model and check the performance afterwards with test data**.
#
# #### Model with adjusted class weights & biases
# The net effect is similar to just adjusting the class weights.

# %% [markdown]
# ### Oversampling the data
#
# In order to be able to provide enough examples to the neural network for positive class - let's oversample the data using ```imblearn``` package.

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(sampling_strategy = 'minority' ,k_neighbors = 5, random_state=1)
X_train_up, y_train_up = sm.fit_resample(X_train, y_train)
print(f'X_train_upsampled: {X_train_up.shape}')
print(f'y_train_upsampled: {y_train_up.shape}')
# Out:
# X_train_upsampled: (12740, 11)
# y_train_upsampled: (12740,)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
model_upsampled = create_model()
training_history_5 = model_upsampled.fit(
    X_train_up, 
    y_train_up, 
    epochs=30,
    validation_split = 0.2,
    #callbacks=[early_stopping],
    batch_size=256,
    verbose=True)
# Out:
# Epoch 1/30
# 40/40 [==============================] - 3s 30ms/step - loss: 0.6573 - mse: 0.2176 - t_pos: 2125.0000 - f_pos: 2232.0000 - t_neg: 5731.0000 - f_neg: 2104.0000 - accuracy: 0.6444 - precision: 0.4877 - recall: 0.5025 - auc: 0.6711 - prc: 0.4916 - val_loss: 0.8407 - val_mse: 0.3005 - val_t_pos: 1384.0000 - val_f_pos: 0.0000e+00 - val_t_neg: 0.0000e+00 - val_f_neg: 1164.0000 - val_accuracy: 0.5432 - val_precision: 1.0000 - val_recall: 0.5432 - val_auc: 0.0000e+00 - val_prc: 1.0000
# Epoch 2/30
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5340 - mse: 0.1785 - t_pos: 2300.0000 - f_pos: 1126.0000 - t_neg: 5244.0000 - f_neg: 1522.0000 - accuracy: 0.7402 - precision: 0.6713 - recall: 0.6018 - auc: 0.7898 - prc: 0.6772 - val_loss: 0.7131 - val_mse: 0.2430 - val_t_pos: 1641.0000 - val_f_pos: 0.0000e+00 - val_t_neg: 0.0000e+00 - val_f_neg: 907.0000 - val_accuracy: 0.6440 - val_precision: 1.0000 - val_recall: 0.6440 - val_auc: 0.0000e+00 - val_prc: 1.0000
# ...

# %%
see_loss(training_history_5, "Loss", 0)

# %%
see_mse(training_history_5, "Loss", 0)

# %%
plot_metrics(training_history_5)

# %%
y_predict_upsampled = model_upsampled.predict(X_test)
create_confusion_matrix(y_test, y_predict_upsampled)
# Out:
# True Negatives:  1406
# False Positives:  187
# False Negatives:  153
# True Positives:  254
# Total Positives:  407

# %%
performance_upsampled = model_upsampled.evaluate(X_test, y_test, verbose=True)
model_performance_upsampled_df = pd.DataFrame(index=[
    'loss', 'mse', 'true positives', 'false positives', 'true negatives', 'false negatives', 
    'accuracy', 'precision', 'recall', 'auc', 'precison recall curve'])
model_performance_upsampled_df['values'] = performance_upsampled
model_performance_upsampled_df.head(100)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.3908 - mse: 0.1225 - t_pos: 254.0000 - f_pos: 187.0000 - t_neg: 1406.0000 - f_neg: 153.0000 - accuracy: 0.8300 - precision: 0.5760 - recall: 0.6241 - auc: 0.8460 - prc: 0.6768
#                             values
# loss                      0.390822
# mse                       0.122527
# true positives          254.000000
# false positives         187.000000
# true negatives         1406.000000
# false negatives         153.000000
# accuracy                  0.830000
# precision                 0.575964
# recall                    0.624079
# auc                       0.846032
# precison recall curve     0.676767

# %%
performance_upsampled_training = model_upsampled.evaluate(X_train, y_train, verbose=True)
model_performance_upsampled_training_df = pd.DataFrame(index=[
    'loss', 'mse', 'true positives', 'false positives', 'true negatives', 'false negatives', 
    'accuracy', 'precision', 'recall', 'auc', 'precison recall curve'])
model_performance_upsampled_training_df['values'] = performance_upsampled_training
model_performance_upsampled_training_df.head(100)
# Out:
# 250/250 [==============================] - 2s 2ms/step - loss: 0.3586 - mse: 0.1119 - t_pos: 1109.0000 - f_pos: 702.0000 - t_neg: 5668.0000 - f_neg: 521.0000 - accuracy: 0.8471 - precision: 0.6124 - recall: 0.6804 - auc: 0.8780 - prc: 0.7216
#                             values
# loss                      0.358560
# mse                       0.111877
# true positives         1109.000000
# false positives         702.000000
# true negatives         5668.000000
# false negatives         521.000000
# accuracy                  0.847125
# precision                 0.612369
# recall                    0.680368
# auc                       0.878020
# precison recall curve     0.721602

# %% [markdown]
# # Model Performance Evaluation
#
# - Evaluate the model on different performance metrics and comment on the performance and scope of improvement
#
# ## Model Performance
# The model performance has improved after upsampling the data which implies that adding more synthetic examples for the positive class helped the model. The model is generalizing well (there is no overfitting seen). The metric values are better than previous models built. We haven't seen any significant change in the accuracy however the precision & recall have improved.
#
# # Conclusion and key takeaways
#
# The data that we had did not contain good predictors for the target variable. Also the dataset was relatively small (considering deep learning). We can make following recommendations:
# 1. Collect more predictors like contact frequency, average monthly transactions and also send satisfaction surveys to collect additional signals.
# 2. Collect more examples of positive classes.

# %% [markdown]
# # Notebook overall
# - Structure and flow: I have followed the step by step tasks listed in scoring guide.
# - Well commented code: I have added comments where needed.
